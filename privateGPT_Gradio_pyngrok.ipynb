# %% [markdown]
# <a href="https://colab.research.google.com/github/rypotter/depo/blob/master/privateGPT_Gradio_pyngrok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/imartinez/privateGPT
#
# https://docs.privategpt.dev/overview/welcome/quickstart
#
# https://docs.privategpt.dev/installation
#
# https://github.com/elise-chin/poetry-and-colab/blob/main/Using_python_poetry_in_Google_Colab.ipynb

# %%
#!python --version #Python 3.10.12
#!python3 --version #Python 3.10.12
#!pip --version #pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
#!uname -a #Linux 53fe6770cbc1 6.1.58+ #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux
#!cat /etc/os-release #PRETTY_NAME="Ubuntu 22.04.3 LTS"
#!whoami #root
# !python --version && whoami && cat /etc/os-release && pwd && ls -al # 3.10.12 /content

# %%
# !add-apt-repository ppa:deadsnakes/ppa && apt update && apt upgrade && apt-get install python3.11 # Enter-t kér!!!

# %%
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1 && update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 2
# !update-alternatives --config python3 #choose 2 for python 3.11 !!!
# Out:
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in auto mode
# update-alternatives: using /usr/bin/python3.11 to provide /usr/bin/python3 (python3) in auto mode
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.11   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.11   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2

# %%
# !apt install python-is-python3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   python-is-python3
# 0 upgraded, 1 newly installed, 0 to remove and 5 not upgraded.
# Need to get 2,788 B of archives.
# After this operation, 13.3 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 python-is-python3 all 3.9.2-2 [2,788 B]
# Fetched 2,788 B in 0s (14.6 kB/s)
# Selecting previously unselected package python-is-python3.
# (Reading database ... 122361 files and directories currently installed.)
# Preparing to unpack .../python-is-python3_3.9.2-2_all.deb ...
# Unpacking python-is-python3 (3.9.2-2) ...
# Setting up python-is-python3 (3.9.2-2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !apt install python3-pip && pip --version
# !apt-get install python3.11-dev && apt-get install python3.11-venv

# %%
# !python --version && python3 --version && python3.11 --version && pip --version # Python 3.11.7
# Out:
# Python 3.11.7
# Python 3.11.7
# Python 3.11.7
# pip 22.0.2 from /usr/lib/python3/dist-packages/pip (python 3.11)

# %%
# !nvcc --version && nvidia-smi
# Build cuda_12.2.r12.2 - GPU-hoz kell
# Tesla T4

# %%
# !git clone https://github.com/imartinez/privateGPT

# %%
# !cd privateGPT && \
python3.11 -m venv venv && source venv/bin/activate && \
pip install --upgrade pip poetry && poetry install --with ui,local && ./scripts/setup
# poetry run python3.11 -m private_gpt
# Launch the privateGPT API server **and** the gradio UI
#!poetry run python3.11 -m private_gpt

# In another terminal, create a new browser window on your private GPT!
#!open http://127.0.0.1:8001/
# Out:
# Requirement already satisfied: pip in ./venv/lib/python3.11/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/15/aa/3f4c7bcee2057a76562a5b33ecbd199be08cdb4443a02e26bd2c3cf6fc39/pip-23.3.2-py3-none-any.whl.metadata
#   Using cached pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting poetry
#   Obtaining dependency information for poetry from https://files.pythonhosted.org/packages/79/94/95c62fb8463d3f7dd86f1fc27369f63b4e028cbdbc7f62716183d4f51d16/poetry-1.7.1-py3-none-any.whl.metadata
#   Using cached poetry-1.7.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting build<2.0.0,>=1.0.3 (from poetry)
#   Obtaining dependency information for build<2.0.0,>=1.0.3 from https://files.pythonhosted.org/packages/93/dd/b464b728b866aaa62785a609e0dd8c72201d62c5f7c53e7c20f4dceb085f/build-1.0.3-py3-none-any.whl.metadata
#   Using cached build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting cachecontrol[filecache]<0.14.0,>=0.13.0 (from poetry)
#   Obtaining dependency information for cachecontrol[filecache]<0.14.0,>=0.13.0 from https://files.pythonhosted.org/packages/1d/e3/a22348e6226dcd585d5a4b5f0175b3a16dabfd3912cbeb02f321d00e56c7/cachecontrol-0.13.1-py3-none-any.whl.metadata
#   Using cached cachecontrol-0.13.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting cleo<3.0.0,>=2.1.0 (from poetry)
#   Obtaining dependency information for cleo<3.0.0,>=2.1.0 from https://files.pythonhosted.org/packages/2d/f5/6bbead8b880620e5a99e0e4bb9e22e67cca16ff48d54105302a3e7821096/cleo-2.1.0-py3-none-any.whl.metadata
#   Using cached cleo-2.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting crashtest<0.5.0,>=0.4.1 (from poetry)
#   Using cached crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Collecting dulwich<0.22.0,>=0.21.2 (from poetry)
#   Obtaining dependency information for dulwich<0.22.0,>=0.21.2 from https://files.pythonhosted.org/packages/d3/42/4f9d76a5d6dc9a952553418379d17364c161c0d3da6e5dfff6d5e455c666/dulwich-0.21.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached dulwich-0.21.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting fastjsonschema<3.0.0,>=2.18.0 (from poetry)
#   Obtaining dependency information for fastjsonschema<3.0.0,>=2.18.0 from https://files.pythonhosted.org/packages/9c/b9/79691036d4a8f9857e74d1728b23f34f583b81350a27492edda58d5604e1/fastjsonschema-2.19.1-py3-none-any.whl.metadata
#   Using cached fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting installer<0.8.0,>=0.7.0 (from poetry)
#   Using cached installer-0.7.0-py3-none-any.whl (453 kB)
# Collecting keyring<25.0.0,>=24.0.0 (from poetry)
#   Obtaining dependency information for keyring<25.0.0,>=24.0.0 from https://files.pythonhosted.org/packages/e3/e9/c51071308adc273ed612cd308a4b4360ffd291da40b7de2f47c9d6e3a978/keyring-24.3.0-py3-none-any.whl.metadata
#   Using cached keyring-24.3.0-py3-none-any.whl.metadata (20 kB)
# Collecting packaging>=20.5 (from poetry)
#   Obtaining dependency information for packaging>=20.5 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pexpect<5.0.0,>=4.7.0 (from poetry)
#   Obtaining dependency information for pexpect<5.0.0,>=4.7.0 from https://files.pythonhosted.org/packages/9e/c3/059298687310d527a58bb01f3b1965787ee3b40dce76752eda8b44e9a2c5/pexpect-4.9.0-py2.py3-none-any.whl.metadata
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pkginfo<2.0.0,>=1.9.4 (from poetry)
#   Using cached pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting platformdirs<4.0.0,>=3.0.0 (from poetry)
#   Obtaining dependency information for platformdirs<4.0.0,>=3.0.0 from https://files.pythonhosted.org/packages/56/29/3ec311dc18804409ecf0d2b09caa976f3ae6215559306b5b530004e11156/platformdirs-3.11.0-py3-none-any.whl.metadata
#   Using cached platformdirs-3.11.0-py3-none-any.whl.metadata (11 kB)
# Collecting poetry-core==1.8.1 (from poetry)
#   Obtaining dependency information for poetry-core==1.8.1 from https://files.pythonhosted.org/packages/99/bc/058b8ff87871fce6615ad032d62c773272f243266b110f7b86d146cf78d8/poetry_core-1.8.1-py3-none-any.whl.metadata
#   Using cached poetry_core-1.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting poetry-plugin-export<2.0.0,>=1.6.0 (from poetry)
#   Obtaining dependency information for poetry-plugin-export<2.0.0,>=1.6.0 from https://files.pythonhosted.org/packages/17/bb/78d7d920bb463e4bee64f44d8b0d4a286a80af7e76ff8326e5169103f44b/poetry_plugin_export-1.6.0-py3-none-any.whl.metadata
#   Using cached poetry_plugin_export-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyproject-hooks<2.0.0,>=1.0.0 (from poetry)
#   Using cached pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting requests<3.0,>=2.26 (from poetry)
#   Obtaining dependency information for requests<3.0,>=2.26 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt<2,>=0.9.1 (from poetry)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting shellingham<2.0,>=1.5 (from poetry)
#   Obtaining dependency information for shellingham<2.0,>=1.5 from https://files.pythonhosted.org/packages/e0/f9/0595336914c5619e5f28a1fb793285925a8cd4b432c9da0a987836c7f822/shellingham-1.5.4-py2.py3-none-any.whl.metadata
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting tomlkit<1.0.0,>=0.11.4 (from poetry)
#   Obtaining dependency information for tomlkit<1.0.0,>=0.11.4 from https://files.pythonhosted.org/packages/6e/43/159750d32481f16e34cc60090b53bc0a14314ad0c1f67a9bb64f3f3a0551/tomlkit-0.12.3-py3-none-any.whl.metadata
#   Using cached tomlkit-0.12.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting trove-classifiers>=2022.5.19 (from poetry)
#   Obtaining dependency information for trove-classifiers>=2022.5.19 from https://files.pythonhosted.org/packages/41/b5/91d44161a56c989c519d53a525787c205b716fb46d57d02ed3a47724ad53/trove_classifiers-2024.1.8-py3-none-any.whl.metadata
#   Using cached trove_classifiers-2024.1.8-py3-none-any.whl.metadata (2.2 kB)
# Collecting virtualenv<21.0.0,>=20.23.0 (from poetry)
#   Obtaining dependency information for virtualenv<21.0.0,>=20.23.0 from https://files.pythonhosted.org/packages/83/22/54b1180756d2d6194bcafb7425d437c3034c4bff92129c3e1e633079e2c4/virtualenv-20.25.0-py3-none-any.whl.metadata
#   Using cached virtualenv-20.25.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting msgpack>=0.5.2 (from cachecontrol[filecache]<0.14.0,>=0.13.0->poetry)
#   Obtaining dependency information for msgpack>=0.5.2 from https://files.pythonhosted.org/packages/df/09/dee50913ba5cc047f7fd7162f09453a676e7935c84b3bf3a398e12108677/msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting filelock>=3.8.0 (from cachecontrol[filecache]<0.14.0,>=0.13.0->poetry)
#   Obtaining dependency information for filelock>=3.8.0 from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from cleo<3.0.0,>=2.1.0->poetry)
#   Obtaining dependency information for rapidfuzz<4.0.0,>=3.0.0 from https://files.pythonhosted.org/packages/c4/94/7b7dc8ecd1357d220636ce154bbfb1ba3eb57d97dc3d1b2c8016bdd43f7a/rapidfuzz-3.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached rapidfuzz-3.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting urllib3>=1.25 (from dulwich<0.22.0,>=0.21.2->poetry)
#   Obtaining dependency information for urllib3>=1.25 from https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl.metadata
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting jaraco.classes (from keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for jaraco.classes from https://files.pythonhosted.org/packages/c7/6b/1bc8fa93ea85146e08f0e0883bc579b7c7328364ed7df90b1628dcb36e10/jaraco.classes-3.3.0-py3-none-any.whl.metadata
#   Using cached jaraco.classes-3.3.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting importlib-metadata>=4.11.4 (from keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for importlib-metadata>=4.11.4 from https://files.pythonhosted.org/packages/c0/8b/d8427f023c081a8303e6ac7209c16e6878f2765d5b59667f3903fbcfd365/importlib_metadata-7.0.1-py3-none-any.whl.metadata
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting SecretStorage>=3.2 (from keyring<25.0.0,>=24.0.0->poetry)
#   Using cached SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2 (from keyring<25.0.0,>=24.0.0->poetry)
#   Using cached jeepney-0.8.0-py3-none-any.whl (48 kB)
# Collecting ptyprocess>=0.5 (from pexpect<5.0.0,>=4.7.0->poetry)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0,>=2.26->poetry)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/40/26/f35951c45070edc957ba40a5b1db3cf60a9dbb1b350c2d5bef03e01e61de/charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3.0,>=2.26->poetry)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl.metadata
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0,>=2.26->poetry)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/64/62/428ef076be88fa93716b576e4a01f919d25968913e817077a386fcbe4f42/certifi-2023.11.17-py3-none-any.whl.metadata
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.23.0->poetry)
#   Obtaining dependency information for distlib<1,>=0.3.7 from https://files.pythonhosted.org/packages/8e/41/9307e4f5f9976bc8b7fea0b66367734e8faf3ec84bc0d412d8cfabbb66cd/distlib-0.3.8-py2.py3-none-any.whl.metadata
#   Using cached distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting cryptography>=2.0 (from SecretStorage>=3.2->keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for cryptography>=2.0 from https://files.pythonhosted.org/packages/62/bd/69628ab50368b1beb900eb1de5c46f8137169b75b2458affe95f2f470501/cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl.metadata
#   Using cached cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Collecting more-itertools (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/50/e2/8e10e465ee3987bb7c9ab69efb91d867d93959095f4807db102d07995d94/more_itertools-10.2.0-py3-none-any.whl.metadata
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting cffi>=1.12 (from cryptography>=2.0->SecretStorage>=3.2->keyring<25.0.0,>=24.0.0->poetry)
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/9b/89/a31c81e36bbb793581d8bba4406a8aac4ba84b2559301c44eef81f4cf5df/cffi-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached cffi-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring<25.0.0,>=24.0.0->poetry)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Using cached poetry-1.7.1-py3-none-any.whl (235 kB)
# Using cached poetry_core-1.8.1-py3-none-any.whl (306 kB)
# Using cached build-1.0.3-py3-none-any.whl (18 kB)
# Using cached cleo-2.1.0-py3-none-any.whl (78 kB)
# Using cached dulwich-0.21.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (516 kB)
# Using cached fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Using cached keyring-24.3.0-py3-none-any.whl (38 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Using cached poetry_plugin_export-1.6.0-py3-none-any.whl (10 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Using cached trove_classifiers-2024.1.8-py3-none-any.whl (13 kB)
# Using cached virtualenv-20.25.0-py3-none-any.whl (3.8 MB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
# Using cached distlib-0.3.8-py2.py3-none-any.whl (468 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Using cached msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (557 kB)
# Using cached rapidfuzz-3.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Using cached cachecontrol-0.13.1-py3-none-any.whl (22 kB)
# Using cached jaraco.classes-3.3.0-py3-none-any.whl (5.9 kB)
# Using cached cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl (4.4 MB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached cffi-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (464 kB)
# Installing collected packages: trove-classifiers, ptyprocess, fastjsonschema, distlib, zipp, urllib3, tomlkit, shellingham, rapidfuzz, pyproject-hooks, pycparser, poetry-core, platformdirs, pkginfo, pip, pexpect, packaging, msgpack, more-itertools, jeepney, installer, idna, filelock, crashtest, charset-normalizer, certifi, virtualenv, requests, jaraco.classes, importlib-metadata, dulwich, cleo, cffi, build, requests-toolbelt, cryptography, cachecontrol, SecretStorage, keyring, poetry-plugin-export, poetry
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed SecretStorage-3.3.3 build-1.0.3 cachecontrol-0.13.1 certifi-2023.11.17 cffi-1.16.0 charset-normalizer-3.3.2 cleo-2.1.0 crashtest-0.4.1 cryptography-41.0.7 distlib-0.3.8 dulwich-0.21.7 fastjsonschema-2.19.1 filelock-3.13.1 idna-3.6 importlib-metadata-7.0.1 installer-0.7.0 jaraco.classes-3.3.0 jeepney-0.8.0 keyring-24.3.0 more-itertools-10.2.0 msgpack-1.0.7 packaging-23.2 pexpect-4.9.0 pip-23.3.2 pkginfo-1.9.6 platformdirs-3.11.0 poetry-1.7.1 poetry-core-1.8.1 poetry-plugin-export-1.6.0 ptyprocess-0.7.0 pycparser-2.21 pyproject-hooks-1.0.0 rapidfuzz-3.6.1 requests-2.31.0 requests-toolbelt-1.0.0 shellingham-1.5.4 tomlkit-0.12.3 trove-classifiers-2024.1.8 urllib3-2.1.0 virtualenv-20.25.0 zipp-3.17.0
# Installing dependencies from lock file
#
# Package operations: 163 installs, 4 updates, 2 removals
#
#   • Removing importlib-metadata (6.11.0): Pending...
#   • Removing importlib-metadata (6.11.0): Removing...
#   • Removing importlib-metadata (6.11.0)
#   • Removing zipp (3.17.0): Pending...
#   • Removing zipp (3.17.0): Removing...
#   • Removing zipp (3.17.0)
#   • Installing frozenlist (1.4.1): Pending...
#   • Installing multidict (6.0.4): Pending...
#   • Installing multidict (6.0.4): Pending...
#   • Installing frozenlist (1.4.1): Installing...
#   • Installing multidict (6.0.4): Pending...
#   • Installing multidict (6.0.4): Installing...
#   • Installing multidict (6.0.4): Installing...
#   • Installing frozenlist (1.4.1)
#   • Installing multidict (6.0.4): Installing...
#   • Installing multidict (6.0.4)
#   • Installing aiosignal (1.3.1): Pending...
#   • Installing attrs (23.1.0): Pending...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing attrs (23.1.0): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing attrs (23.1.0): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing aiosignal (1.3.1): Installing...
#   • Installing attrs (23.1.0): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing attrs (23.1.0): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing aiosignal (1.3.1)
#   • Installing attrs (23.1.0): Installing...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing yarl (1.9.4): Pending...
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing yarl (1.9.4): Pending...
#   • Installing attrs (23.1.0)
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Pending...
#   • Installing six (1.16.0): Pending...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Pending...
#   • Installing wrapt (1.16.0): Pending...
#   • Installing yarl (1.9.4): Pending...
#   • Installing yarl (1.9.4): Pending...
#   • Installing wrapt (1.16.0): Installing...
#   • Installing yarl (1.9.4): Pending...
#   • Installing yarl (1.9.4): Installing...
#   • Installing yarl (1.9.4): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4): Installing...
#   • Installing yarl (1.9.4)
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing six (1.16.0): Installing...
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing six (1.16.0)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing six (1.16.0)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing nvidia-nvjitlink-cu12 (12.3.101): Installing...
#   • Installing six (1.16.0)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18): Installing...
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18)
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing six (1.16.0)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18)
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing nvidia-nvjitlink-cu12 (12.3.101)
#   • Installing six (1.16.0)
#   • Downgrading urllib3 (2.1.0 -> 1.26.18)
#   • Installing wrapt (1.16.0)
#   • Installing yarl (1.9.4)
#   • Installing aiohttp (3.9.1): Pending...
#   • Installing deprecated (1.2.14): Pending...
#   • Installing dill (0.3.7): Pending...
#   • Installing fsspec (2023.12.2): Pending...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing dill (0.3.7): Pending...
#   • Installing fsspec (2023.12.2): Pending...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing deprecated (1.2.14): Installing...
#   • Installing dill (0.3.7): Pending...
#   • Installing fsspec (2023.12.2): Pending...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing dill (0.3.7): Installing...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing markupsafe (2.1.3): Installing...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing dill (0.3.7): Installing...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3): Installing...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing deprecated (1.2.14)
#   • Installing dill (0.3.7): Installing...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3): Installing...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing deprecated (1.2.14)
#   • Installing dill (0.3.7): Installing...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing aiohttp (3.9.1): Installing...
#   • Installing deprecated (1.2.14)
#   • Installing dill (0.3.7): Installing...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing dill (0.3.7)
#   • Installing fsspec (2023.12.2): Installing...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing mpmath (1.3.0): Installing...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Installing...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing fsspec (2023.12.2)
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Installing...
#   • Installing numpy (1.26.0): Pending...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2): Pending...
#   • Installing python-dateutil (2.8.2): Installing...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Pending...
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing numpy (1.26.0): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing numpy (1.26.0): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing mpmath (1.3.0)
#   • Installing numpy (1.26.0): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing pyyaml (6.0.1): Pending...
#   • Installing deprecated (1.2.14)
#   • Installing dill (0.3.7)
#   • Installing fsspec (2023.12.2)
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0)
#   • Installing numpy (1.26.0): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing pyyaml (6.0.1): Pending...
#   • Installing aiohttp (3.9.1)
#   • Installing deprecated (1.2.14)
#   • Installing dill (0.3.7)
#   • Installing fsspec (2023.12.2)
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0)
#   • Installing numpy (1.26.0): Installing...
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing pyyaml (6.0.1): Pending...
#   • Installing rpds-py (0.14.1): Pending...
#   • Installing rpds-py (0.14.1): Pending...
#   • Installing pyyaml (6.0.1): Installing...
#   • Installing rpds-py (0.14.1): Pending...
#   • Installing rpds-py (0.14.1): Installing...
#   • Installing rpds-py (0.14.1): Installing...
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1): Installing...
#   • Installing tqdm (4.66.1): Pending...
#   • Installing tqdm (4.66.1): Installing...
#   • Installing tqdm (4.66.1): Installing...
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1): Installing...
#   • Installing typing-extensions (4.9.0): Pending...
#   • Installing typing-extensions (4.9.0): Pending...
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0): Pending...
#   • Installing tzdata (2023.3): Pending...
#   • Installing tzdata (2023.3): Pending...
#   • Installing typing-extensions (4.9.0): Installing...
#   • Installing tzdata (2023.3): Pending...
#   • Installing tzdata (2023.3): Installing...
#   • Installing tzdata (2023.3): Installing...
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3): Installing...
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3): Installing...
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3): Installing...
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing numpy (1.26.0)
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Pending...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Pending...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cublas-cu12 (12.1.3.1): Installing...
#   • Installing nvidia-cusparse-cu12 (12.1.0.106): Installing...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cusparse-cu12 (12.1.0.106)
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cusparse-cu12 (12.1.0.106)
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing nvidia-cublas-cu12 (12.1.3.1)
#   • Installing nvidia-cusparse-cu12 (12.1.0.106)
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1)
#   • Installing rpds-py (0.14.1)
#   • Installing tqdm (4.66.1)
#   • Installing typing-extensions (4.9.0)
#   • Installing tzdata (2023.3)
#   • Installing h11 (0.14.0): Pending...
#   • Installing huggingface-hub (0.19.4): Pending...
#   • Installing humanfriendly (10.0): Pending...
#   • Installing jinja2 (3.1.2): Pending...
#   • Installing mdurl (0.1.2): Pending...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing mdurl (0.1.2): Pending...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Pending...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing huggingface-hub (0.19.4): Pending...
#   • Installing humanfriendly (10.0): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing h11 (0.14.0): Installing...
#   • Installing huggingface-hub (0.19.4): Pending...
#   • Installing humanfriendly (10.0): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing humanfriendly (10.0): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing huggingface-hub (0.19.4): Installing...
#   • Installing humanfriendly (10.0): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing humanfriendly (10.0): Installing...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing networkx (3.2.1): Pending...
#   • Installing networkx (3.2.1): Pending...
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing huggingface-hub (0.19.4): Installing...
#   • Installing humanfriendly (10.0): Installing...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing h11 (0.14.0)
#   • Installing huggingface-hub (0.19.4): Installing...
#   • Installing humanfriendly (10.0): Installing...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing jinja2 (3.1.2)
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing jinja2 (3.1.2)
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing humanfriendly (10.0)
#   • Installing jinja2 (3.1.2)
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing networkx (3.2.1): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   • Installing networkx (3.2.1): Installing...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   • Installing networkx (3.2.1): Installing...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   • Installing multiprocess (0.70.15)
#   • Installing networkx (3.2.1): Installing...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Pending...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing humanfriendly (10.0)
#   • Installing jinja2 (3.1.2)
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15)
#   • Installing networkx (3.2.1): Installing...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing huggingface-hub (0.19.4)
#   • Installing humanfriendly (10.0)
#   • Installing jinja2 (3.1.2)
#   • Installing mdurl (0.1.2)
#   • Installing multiprocess (0.70.15)
#   • Installing networkx (3.2.1): Installing...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105): Installing...
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   • Installing networkx (3.2.1)
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Pending...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-cuda-cupti-cu12 (12.1.105)
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105): Installing...
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-cuda-nvrtc-cu12 (12.1.105)
#   • Installing nvidia-cuda-runtime-cu12 (12.1.105)
#   • Installing nvidia-cudnn-cu12 (8.9.2.26): Pending...
#   • Installing nvidia-cufft-cu12 (11.0.2.54): Installing...
#   • Installing nvidia-curand-cu12 (10.3.2.106): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105): Installing...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Pending...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing pandas (2.1.4): Installing...
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Installing...
#   • Installing nvidia-curand-cu12 (10.3.2.106)
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   • Installing nvidia-nccl-cu12 (2.18.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Installing...
#   • Installing protobuf (4.25.1): Pending...
#   • Installing protobuf (4.25.1): Installing...
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Pending...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Installing...
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Pending...
#   • Installing nvidia-nccl-cu12 (2.18.1): Installing...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4): Installing...
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Pending...
# Installing /content/privateGPT/venv/lib/python3.11/site-packages/nvidia/__init__.py over existing file
#   • Installing pyarrow (14.0.1): Installing...
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Installing...
#   • Installing pandas (2.1.4)
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Installing...
#   • Installing referencing (0.32.0): Pending...
#   • Installing referencing (0.32.0): Installing...
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2): Pending...
#   • Updating setuptools (65.5.0 -> 69.0.2): Installing...
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0): Pending...
#   • Installing sniffio (1.3.0): Installing...
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12): Pending...
#   • Installing sympy (1.12): Installing...
#   • Installing nvidia-curand-cu12 (10.3.2.106)
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   • Installing nvidia-nccl-cu12 (2.18.1): Installing...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4)
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Installing...
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12): Installing...
#   • Installing nvidia-cufft-cu12 (11.0.2.54)
#   • Installing nvidia-curand-cu12 (10.3.2.106)
#   • Installing nvidia-cusolver-cu12 (11.4.5.107): Installing...
#   • Installing nvidia-nccl-cu12 (2.18.1): Installing...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4)
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1): Installing...
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12): Installing...
#   • Installing triton (2.1.0): Pending...
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12): Installing...
#   • Installing triton (2.1.0): Pending...
#   • Installing pyarrow (14.0.1)
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12): Installing...
#   • Installing triton (2.1.0): Pending...
#   • Installing xxhash (3.4.1): Pending...
#   • Installing xxhash (3.4.1): Installing...
#   • Installing xxhash (3.4.1)
#   • Installing triton (2.1.0): Pending...
#   • Installing xxhash (3.4.1)
#   • Installing sympy (1.12)
#   • Installing triton (2.1.0): Pending...
#   • Installing xxhash (3.4.1)
#   • Installing nvidia-nccl-cu12 (2.18.1): Installing...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4)
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1)
#   • Installing referencing (0.32.0)
#   • Updating setuptools (65.5.0 -> 69.0.2)
#   • Installing sniffio (1.3.0)
#   • Installing sympy (1.12)
#   • Installing triton (2.1.0): Pending...
#   • Installing xxhash (3.4.1)
#   • Installing nvidia-cusolver-cu12 (11.4.5.107)
#   • Installing nvidia-nccl-cu12 (2.18.1): Installing...
#   • Installing nvidia-nvtx-cu12 (12.1.105)
#   • Installing pandas (2.1.4)
#   • Installing protobuf (4.25.1)
#   • Installing pyarrow (14.0.1)
# ...
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0): Installing...
#   • Installing torchvision (0.16.2): Installing...
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing sqlalchemy (2.0.23)
#   • Installing tenacity (8.2.3)
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0): Installing...
#   • Installing torchvision (0.16.2): Installing...
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing torchvision (0.16.2): Installing...
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0)
#   • Installing torchvision (0.16.2): Installing...
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing torchvision (0.16.2)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing nest-asyncio (1.5.8)
#   • Installing nltk (3.8.1)
#   • Installing nodeenv (1.8.0)
#   • Installing openai (1.5.0)
#   • Installing optimum (1.16.1)
#   • Installing orjson (3.9.10)
#   • Installing pathspec (0.12.1)
#   • Installing portalocker (2.8.2)
#   • Installing pydantic-extra-types (2.2.0)
#   • Installing pydantic-settings (2.1.0)
#   • Installing pydub (0.25.1)
#   • Installing pytest (7.4.3)
#   • Installing python-multipart (0.0.6)
#   • Installing s3transfer (0.9.0)
#   • Installing scikit-learn (1.3.2): Installing...
#   • Installing semantic-version (2.10.0)
#   • Installing sqlalchemy (2.0.23)
#   • Installing tenacity (8.2.3)
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0)
#   • Installing torchvision (0.16.2)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing matplotlib (3.8.2)
#   • Installing nest-asyncio (1.5.8)
#   • Installing nltk (3.8.1)
#   • Installing nodeenv (1.8.0)
#   • Installing openai (1.5.0)
#   • Installing optimum (1.16.1)
#   • Installing orjson (3.9.10)
#   • Installing pathspec (0.12.1)
#   • Installing portalocker (2.8.2)
#   • Installing pydantic-extra-types (2.2.0)
#   • Installing pydantic-settings (2.1.0)
#   • Installing pydub (0.25.1)
#   • Installing pytest (7.4.3)
#   • Installing python-multipart (0.0.6)
#   • Installing s3transfer (0.9.0)
#   • Installing scikit-learn (1.3.2): Installing...
#   • Installing semantic-version (2.10.0)
#   • Installing sqlalchemy (2.0.23)
#   • Installing tenacity (8.2.3)
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0)
#   • Installing torchvision (0.16.2)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing semantic-version (2.10.0)
#   • Installing sqlalchemy (2.0.23)
#   • Installing tenacity (8.2.3)
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0)
#   • Installing torchvision (0.16.2)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing scikit-learn (1.3.2)
#   • Installing semantic-version (2.10.0)
#   • Installing sqlalchemy (2.0.23)
#   • Installing tenacity (8.2.3)
#   • Installing tiktoken (0.5.2)
#   • Downgrading tomlkit (0.12.3 -> 0.12.0)
#   • Installing torchvision (0.16.2)
#   • Installing typer (0.9.0)
#   • Installing ujson (5.9.0)
#   • Installing uvicorn (0.24.0.post1)
#   • Installing black (22.12.0): Pending...
#   • Installing boto3 (1.34.2): Pending...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0): Pending...
#   • Installing llama-cpp-python (0.2.23): Pending...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing llama-cpp-python (0.2.23): Pending...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing injector (0.21.0): Installing...
#   • Installing llama-cpp-python (0.2.23): Pending...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0): Installing...
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing boto3 (1.34.2): Installing...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0): Installing...
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Pending...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing boto3 (1.34.2): Installing...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing black (22.12.0): Installing...
#   • Installing boto3 (1.34.2): Installing...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing boto3 (1.34.2)
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing pre-commit (2.21.0): Pending...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing boto3 (1.34.2)
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing black (22.12.0)
#   • Installing boto3 (1.34.2)
#   • Installing gradio (4.10.0): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Pending...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing pypdf (3.17.2): Pending...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing pypdf (3.17.2): Pending...
#   • Installing mypy (1.7.1): Installing...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing pypdf (3.17.2): Pending...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Installing...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing pypdf (3.17.2): Pending...
#   • Installing gradio (4.10.0): Installing...
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3): Installing...
#   • Installing mypy (1.7.1): Installing...
#   • Installing pre-commit (2.21.0): Installing...
#   • Installing pypdf (3.17.2): Pending...
#   • Installing pypdf (3.17.2): Installing...
#   • Installing pypdf (3.17.2): Installing...
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2): Installing...
#   • Installing pytest-asyncio (0.21.1): Pending...
#   • Installing pytest-asyncio (0.21.1): Installing...
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0): Pending...
#   • Installing pytest-cov (3.0.0): Installing...
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0): Installing...
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0): Installing...
#   • Installing qdrant-client (1.7.0): Pending...
#   • Installing qdrant-client (1.7.0): Pending...
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0): Pending...
#   • Installing ruff (0.1.8): Pending...
#   • Installing ruff (0.1.8): Pending...
#   • Installing qdrant-client (1.7.0): Installing...
#   • Installing ruff (0.1.8): Pending...
#   • Installing ruff (0.1.8): Pending...
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8): Pending...
#   • Installing sentence-transformers (2.2.2): Pending...
#   • Installing sentence-transformers (2.2.2): Installing...
#   • Installing sentence-transformers (2.2.2): Installing...
#   • Installing ruff (0.1.8): Installing...
#   • Installing sentence-transformers (2.2.2): Installing...
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12): Pending...
#   • Installing types-pyyaml (6.0.12.12): Installing...
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0): Pending...
#   • Installing watchdog (3.0.0): Installing...
#   • Installing watchdog (3.0.0)
#   • Installing mypy (1.7.1): Installing...
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8): Installing...
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1): Installing...
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8): Installing...
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing gradio (4.10.0)
#   • Installing injector (0.21.0)
#   • Installing llama-cpp-python (0.2.23): Preparing...
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing llama-cpp-python (0.2.23): Installing...
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#   • Installing llama-cpp-python (0.2.23)
#   • Installing llama-index (0.9.3)
#   • Installing mypy (1.7.1)
#   • Installing pre-commit (2.21.0)
#   • Installing pypdf (3.17.2)
#   • Installing pytest-asyncio (0.21.1)
#   • Installing pytest-cov (3.0.0)
#   • Installing qdrant-client (1.7.0)
#   • Installing ruff (0.1.8)
#   • Installing sentence-transformers (2.2.2)
#   • Installing types-pyyaml (6.0.12.12)
#   • Installing watchdog (3.0.0)
#
# Installing the current project: private-gpt (0.2.0)Installing the current project: private-gpt (0.2.0)
# 18:23:36.063 [INFO    ] private_gpt.settings.settings_loader - Starting application with profiles=['default']
# Downloading embedding BAAI/bge-small-en-v1.5
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 793kB/s]
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 13.9MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:08,  1.34it/s]
# modules.json: 100% 349/349 [00:00<00:00, 2.09MB/s]
#
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 279kB/s]
#
# config.json: 100% 743/743 [00:00<00:00, 6.60MB/s]
#
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.66MB/s]
#
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 1.04MB/s]
#
# tokenizer.json:   0% 0.00/711k [00:00<?, ?B/s]
#
# README.md:   0% 0.00/90.3k [00:00<?, ?B/s]
#
#
# README.md: 100% 90.3k/90.3k [00:00<00:00, 3.73MB/s]
# Fetching 13 files:  23% 3/13 [00:00<00:02,  3.93it/s]
#
# tokenizer_config.json: 100% 366/366 [00:00<00:00, 2.21MB/s]
#
#
# vocab.txt: 100% 232k/232k [00:00<00:00, 6.89MB/s]
#
# tokenizer.json: 100% 711k/711k [00:00<00:00, 6.54MB/s]
#
# pytorch_model.bin:   0% 0.00/134M [00:00<?, ?B/s]
#
#
# model.safetensors:   8% 10.5M/133M [00:00<00:01, 98.7MB/s]
# pytorch_model.bin:   8% 10.5M/134M [00:00<00:01, 100MB/s]
#
#
# model.safetensors:  24% 31.5M/133M [00:00<00:00, 155MB/s]
# pytorch_model.bin:  24% 31.5M/134M [00:00<00:00, 161MB/s]
#
#
# model.safetensors:  39% 52.4M/133M [00:00<00:00, 172MB/s]
# pytorch_model.bin:  39% 52.4M/134M [00:00<00:00, 179MB/s]
#
#
# model.safetensors:  55% 73.4M/133M [00:00<00:00, 167MB/s]
# pytorch_model.bin:  55% 73.4M/134M [00:00<00:00, 171MB/s]
#
#
# model.safetensors:  71% 94.4M/133M [00:00<00:00, 144MB/s]
# pytorch_model.bin:  71% 94.4M/134M [00:00<00:00, 149MB/s]
#
#
# model.safetensors:  86% 115M/133M [00:00<00:00, 148MB/s]
# pytorch_model.bin:  86% 115M/134M [00:00<00:00, 154MB/s]
#
#
# model.safetensors: 100% 133M/133M [00:00<00:00, 146MB/s]
# Fetching 13 files:  46% 6/13 [00:01<00:02,  3.50it/s]
# pytorch_model.bin: 100% 134M/134M [00:00<00:00, 150MB/s]
# Fetching 13 files: 100% 13/13 [00:01<00:00,  6.96it/s]
# Embedding model downloaded!
# Downloading LLM mistral-7b-instruct-v0.2.Q4_K_M.gguf
# mistral-7b-instruct-v0.2.Q4_K_M.gguf: 100% 4.37G/4.37G [00:33<00:00, 130MB/s]
# LLM model downloaded!
# Downloading tokenizer mistralai/Mistral-7B-Instruct-v0.2
# Tokenizer downloaded!
# Setup done

# %%
# EZ csak a GPU-hoz kell, GPU nélkül kihagyjuk, GPU-val nem müxik:!!!!!!!!!!!!!!!!!!
# !cd privateGPT && source venv/bin/activate && CMAKE_ARGS='-DLLAMA_CUBLAS=on' poetry run pip install --force-reinstall --no-cache-dir llama-cpp-python

# %%
# ngrok
# !cd privateGPT && source venv/bin/activate && pip install nest-asyncio pyngrok

# %%
# Itt, indítás előtt beszúrni a private_gpt/__main__.py-be ezt:

#====================
#import nest_asyncio
#from pyngrok import ngrok, conf
#
#conf.get_default().auth_token = "2aUPfvz6scs612VfSIEtz2ypD76_4CGJwKgT5gVXiwqhsMWB6" # getpass.getpass()
#ngrok_tunnel = ngrok.connect(8001) # 8000)
#print('Public URL:', ngrok_tunnel.public_url)
#nest_asyncio.apply()
#====================

# Launch the privateGPT API server **and** the gradio UI
# !cd privateGPT && source venv/bin/activate && poetry run python3.11 -m private_gpt

# In another terminal, create a new browser window on your private GPT!
#!open http://127.0.0.1:8001/ # remote URL open in new browser window

# %%
# !rm -rf privateGPT/venv
