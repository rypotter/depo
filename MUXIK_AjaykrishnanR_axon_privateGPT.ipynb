# %% [markdown]
# <a href="https://colab.research.google.com/github/rypotter/depo/blob/master/MUXIK_AjaykrishnanR_axon_privateGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/drive/1yFUIo7jxEVRwiojVUETHE5bVvPPVk9gl?usp=sharing#scrollTo=-zHfNwW56-_w

# %% [markdown]
# Ez müxik, valamelyest

# %%
# !git clone https://github.com/AjaykrishnanR-axon/privateGPT.git
# !pip3 install -r /content/privateGPT/requirements.txt
# !pip install sentence_transformers
# !pip install huggingface_hub
# Másodszorra, ezzel a módosítással müxik:
#!CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python --force-reinstall --upgrade --no-cache-dir
# !pip install llama-cpp-python==0.1.65 --force-reinstall --upgrade --no-cache-dir
# Out:
# fatal: destination path 'privateGPT' already exists and is not an empty directory.
# ...
#   Using cached llama_cpp_python-0.1.68-cp310-cp310-linux_x86_64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 36.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2
#     Uninstalling numpy-1.26.2:
#       Successfully uninstalled numpy-1.26.2
#   Attempting uninstall: llama-cpp-python
#     Found existing installation: llama_cpp_python 0.2.24
#     Uninstalling llama_cpp_python-0.2.24:
#       Successfully uninstalled llama_cpp_python-0.2.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(repo_id="TheBloke/Nous-Hermes-Llama2-GGML", filename="nous-hermes-llama2-13b.ggmlv3.q4_1.bin", local_dir="/content/privateGPT/models/")
# Out:
# nous-hermes-llama2-13b.ggmlv3.q4_1.bin:   0%|          | 0.00/8.14G [00:00<?, ?B/s]
# '/content/privateGPT/models/nous-hermes-llama2-13b.ggmlv3.q4_1.bin'

# %%
# !python /content/privateGPT/ingest.py
# Out:
# Appending to existing vectorstore at db
# Loading documents from /content/privateGPT/source_documents/
# Loading new documents: 0it [00:00, ?it/s]
# No new documents to load

# %%
# !python /content/privateGPT/privateGPT.py
# /content/privateGPT/models/nous-hermes-llama2-13b.ggmlv3.q4_1.bin
# Out:
# llama.cpp: loading model from /content/privateGPT/models/nous-hermes-llama2-13b.ggmlv3.q4_1.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32032
# llama_model_load_internal: n_ctx      = 2048
# llama_model_load_internal: n_embd     = 5120
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 40
# llama_model_load_internal: n_layer    = 40
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: ftype      = 3 (mostly Q4_1)
# llama_model_load_internal: n_ff       = 13824
# llama_model_load_internal: n_parts    = 1
# llama_model_load_internal: model size = 13B
# llama_model_load_internal: ggml ctx size =    0.09 MB
# llama_model_load_internal: mem required  = 9807.68 MB (+ 1608.00 MB per state)
# ....................................................................................................
# llama_init_from_file: kv self size  = 1600.00 MB
#
# ...

# %%
# !rm -rf /content/privateGPT
# !pwd && !ls -al /content/privateGPT/models/
# Out:
# /content
# /bin/bash: line 1: !ls: command not found
